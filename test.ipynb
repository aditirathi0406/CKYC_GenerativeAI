# %%
import easyocr
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
Image_PATH =r'C:\Users\diksh\OneDrive\Desktop\download (2).jpg'

# %%
reader= easyocr.Reader(['en'],gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
result= reader.readtext(Image_PATH)
text_list = [item[1] for item in result]

text_list
# Out:
# ['HRT TTR',
#  'Government of India',
#  'TrTG &MT',
#  'MERAJ KHAN',
#  '74at',
#  'geq <M',
#  'Father',
#  'Sudhdan Khan',
#  'SH',
#  'Tf',
#  'DOB',
#  '12/12/1988',
#  '964',
#  'Male',
#  '2943 6593 3461',
#  'HTUR',
#  '31H  31qd} &T 3fu3R',
#  'HRy @anrez 4UIG Sifearut',
#  'Unique Identification Authority of India',
#  '9T:',
#  'TZ',
#  'GG %16 , #crilall,',
#  'Address: saray dan shah; KATRAULI;',
#  '3,',
#  'Rc9r, Salraic,',
#  'Src 4a?1,',
#  'Poore Durgi; Phoolpur; Allahabad; Ultar',
#  '212402',
#  'Pradesh; 212402',
#  '2943 6593 3461',
#  'WWI',
#  '1947',
#  '1800 300 1947',
#  'nelp Quidai govin',
#  'KUidai',
#  'gov-In']

# %%
top_left= tuple(result[0][0][0])
bottom_right=tuple(result [0][0][2])
text =result[0][1]
font=cv2.FONT_HERSHEY_SIMPLEX

# %%
img=cv2.imread(Image_PATH)
img= cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
img=cv2.putText(img,text,top_left ,font,.5,(255,255,255),cv2.LINE_AA)
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
